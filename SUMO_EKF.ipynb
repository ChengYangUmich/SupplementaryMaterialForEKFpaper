# %%
from dynamita.sumon import dur, Sumo
import numpy as np
import pandas as pd
import time
import os
import shutil
import matplotlib.pyplot as plt
import xlrd
# from cyEKF import MLEEKF

# %%
from filterpy.kalman import ExtendedKalmanFilter as EKF
from copy import deepcopy
class MLEEKF(EKF):
    def __init__(self,M):
        EKF.__init__(self,4,1,7)
        self.dt = 1/144
        self.V = 2000 # initialize constant parameters 
        self.KNH = 0.5
        self.KO1 = 0.6
        self.KO2 = 0.4
        self.KO3 = 0.2 
        self.fr = 0.7 
        self.M = M
    
    ## using the symbolic results above to define state prediction function f(x,u)
    def fxu(self,x,u):
        x =x.reshape(-1)
        dt = self.dt
        V = self.V
        KNH = self.KNH
        KO1 = self.KO1
        KO2 = self.KO2
        KO3 = self.KO3
        fr = self.fr
    
    
        SNH1 = x[0]
        SNH2 = x[1]
        SNH3 = x[2]
        r = x[3]
    
        QPE  = u[0]
        QRAS = u[1]
        QMLE = u[2]
        TKN  = u[3]
    
        SO1 = u[4]
        SO2 = u[5]
        SO3 = u[6]
        x_next = np.array([[SNH1 + dt*(QPE*TKN*fr/V + SNH1*(-QMLE - QPE - QRAS)/V + SNH3*(QMLE + QRAS)/V + SO1*r/(KO1 + SO1))], 
                           [SNH2 + dt*(SNH1*(QMLE + QPE + QRAS)/V + SNH2*SO2*r/((KNH + SNH2)*(KO2 + SO2)) + SNH2*(-QMLE - QPE - QRAS)/V)],
                           [SNH3 + dt*(SNH2*(QMLE + QPE + QRAS)/V + SNH3*SO3*r/((KNH + SNH3)*(KO3 + SO3)) + SNH3*(-QMLE - QPE - QRAS)/V)], 
                           [r]])
        return x_next
        
    ## using the symbolic results above to define jacobian of the state transition function over state,dfdx  
    def F_j(self,x,u):
        x =x.reshape(-1)
        dt = self.dt
        V = self.V
        KNH = self.KNH
        KO1 = self.KO1
        KO2 = self.KO2
        KO3 = self.KO3
        fr = self.fr
    
    
        SNH1 = x[0]
        SNH2 = x[1]
        SNH3 = x[2]
        r = x[3]
    
        QPE  = u[0]
        QRAS = u[1]
        QMLE = u[2]
        TKN  = u[3]
    
        SO1 = u[4]
        SO2 = u[5]
        SO3 = u[6]
        # dFdx should be a 4 by 4 matrix 
        dFdx = np.array([[1 + dt*(-QMLE - QPE - QRAS)/V, 0, dt*(QMLE + QRAS)/V, SO1*dt/(KO1 + SO1)], 
                         [dt*(QMLE + QPE + QRAS)/V, dt*(-SNH2*SO2*r/((KNH + SNH2)**2*(KO2 + SO2)) + SO2*r/((KNH + SNH2)*(KO2 + SO2)) + (-QMLE - QPE - QRAS)/V) + 1, 0, SNH2*SO2*dt/((KNH + SNH2)*(KO2 + SO2))], 
                         [0, dt*(QMLE + QPE + QRAS)/V, dt*(-SNH3*SO3*r/((KNH + SNH3)**2*(KO3 + SO3)) + SO3*r/((KNH + SNH3)*(KO3 + SO3)) + (-QMLE - QPE - QRAS)/V) + 1, SNH3*SO3*dt/((KNH + SNH3)*(KO3 + SO3))],
                         [0, 0, 0, 1]])
        return dFdx
   
    ## using the symbolic results above to define jacobian of the state transition function over input,dfdu
    def V_j(self,x,u):
        x =x.reshape(-1)
        dt = self.dt
        V = self.V
        KNH = self.KNH
        KO1 = self.KO1
        KO2 = self.KO2
        KO3 = self.KO3
        fr = self.fr
    
    
        SNH1 = x[0]
        SNH2 = x[1]
        SNH3 = x[2]
        r = x[3]
    
        QPE  = u[0]
        QRAS = u[1]
        QMLE = u[2]
        TKN  = u[3]
    
        SO1 = u[4]
        SO2 = u[5]
        SO3 = u[6]
        # dFdx should be a 4 by 7 matrix 
        dFdu = np.array([[dt*(-SNH1/V + TKN*fr/V), dt*(-SNH1/V + SNH3/V), dt*(-SNH1/V + SNH3/V), QPE*dt*fr/V, dt*(-SO1*r/(KO1 + SO1)**2 + r/(KO1 + SO1)), 0, 0],
                         [dt*(SNH1/V - SNH2/V), dt*(SNH1/V - SNH2/V), dt*(SNH1/V - SNH2/V), 0, 0, dt*(-SNH2*SO2*r/((KNH + SNH2)*(KO2 + SO2)**2) + SNH2*r/((KNH + SNH2)*(KO2 + SO2))), 0], 
                         [dt*(SNH2/V - SNH3/V), dt*(SNH2/V - SNH3/V), dt*(SNH2/V - SNH3/V), 0, 0, 0, dt*(-SNH3*SO3*r/((KNH + SNH3)*(KO3 + SO3)**2) + SNH3*r/((KNH + SNH3)*(KO3 + SO3)))],
                         [0, 0, 0, 0, 0, 0, 0]])
        return dFdu
    
    def predict(self,u):
        # Project the state ahead
        self.x = self.fxu(self.x,u)
        # Project the error covariance ahead 
        F = self.F_j(self.x,u).astype(float)
        V = self.V_j(self.x,u).astype(float)
        # covariance of motion noise in control space -std of QPE QMLE QRAS QTKN SO1 SO2 SO3
        M = self.M
        self.P = F @ self.P @ F.T + V @ M @ V.T 
        self.P.astype(float)
        
    def HJacobian(self,x):
        return np.array([[0,0,1,0]]) 


    def hx(self,x):
        return x[2]

    def residual(self,a,b):
        return a-b

    def ekf_update(self,z):
        self.update(np.array([z]),HJacobian=self.HJacobian,Hx = self.hx, residual=self.residual )

# %% [markdown]
# # Step 1: Create the the Extended Kalman Filter object

# %%
# Define the input covaraince matrix 
# Inputs are : QPE, QRAS, QMLE, TKN, SO1, SO2, SO3
in_cov = np.eye(7)
ekf = MLEEKF(in_cov)

# Set the first guess of for the estimated state: SNH1, SNH2, SNH3, r 
# For accuary, I suggest started this fromt 
ekf.x = np.array([6,3,1,-330])

# Set the first guess for the state covariance matrix 
ekf.P = np.diag([1,1,1,20])

# ---------------EKF tuning parameters ----------------------------
# The ratio between Q/R control the speed of convergence 
ekf.R = 0.1   # Measurement noise covariance matrix 
# ekf.Q = np.eye(1)         # Process noise covariance matrix

# %% [markdown]
# # Step 2: Set up the SUMO-python Interface

# %%
sumoPath = "c:/Users/28417/AppData//Local/Dynamita/Sumo20"
licenseFile = "c:/Users/28417/AppData/Roaming/Dynamita/Sumo20/networklicense.sumolic"
model = "C:/Users/28417/Desktop/MIMO_control_design_for_MLE/Openloop.sumo"
initial_file = "C:/Users/28417/Desktop/MIMO_control_design_for_MLE/script_Initialize.scs"

# Check the sumo license 
sumo = Sumo(sumoPath, licenseFile) 

# Add message_callback so that we can see if commands in python are successfully sent to SUMO 
def message_callback(sumo):
    for message in sumo.messages:
        print(message)
    sumo.messages = []
    return 0
sumo.add_message_callback(message_callback)
# Out:
# License OK...

# %%
# Load the sumo model 
if sumo.model_loaded:
    sumo.unload_model()
sumo.load_model(model)   # 0 means successfully loaded 

# Load initial files 
initial_command = ' execute ' + initial_file + ';'
sumo.send_command('reset')
sumo.send_command(initial_command)
# Out:
# Trying to load model: b'C:\\Users\\28417\\AppData\\Local\\Temp\\tmpmy8gslnu\\sumoproject.dll'

# %% [markdown]
# # Define the input functions

# %%
def QPE_fun(t,mean=24000,std=500):
    if t <= 3:
        true_value = mean 
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]     
    else:
        true_value = mean + 5000*np.sin(2*np.pi*t)
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    return true_value,noisy_value

def QRAS_fun(t,mean=24000,std=500):
    true_value = mean
    noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    return true_value,noisy_value

def QMLE_fun(t,mean=36000,std=500):
    true_value = mean
    noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    return true_value,noisy_value

def TKN_fun(t,mean=56.6,std=3):
    if t <= 3:
        true_value = mean 
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]     
    else:
        true_value = mean + 10*np.sin(2*np.pi*t)
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    return true_value,noisy_value

def SO1_fun(t,mean=1.5, std=0.1):
    if t <= 3:
        true_value = mean 
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]     
    else:
        true_value = mean + 1*np.sin(2*np.pi/14*(t-3))
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    return true_value,noisy_value

def SO2_fun(t,mean=1,std=0.1):
    if t <= 3:
        true_value = mean 
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]     
    else:
        true_value = mean + 0.7*np.sin(2*np.pi/14*(t-3))
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    
    return true_value,noisy_value

def SO3_fun(t,mean=0.5,std=0.1):
    if t <= 3:
        true_value = mean 
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]     
    else:
        true_value = mean + 0.2*np.sin(2*np.pi/7*(t-3))
        noisy_value = true_value + std*np.random.randn(1).astype(float)[0]
    if  true_value<0:
        true_value = 0
    if noisy_value<0:
        noisy_value = 0
    return true_value,noisy_value

# %%
# Cell used to evaluate the input_functions
#t_vec = np.arange(0,10,1/144)
#out1_list = np.zeros(t_vec.shape)
#out2_list = np.zeros(t_vec.shape)

#for i,t in enumerate(t_vec):
#    out1,out2 = SO3_fun(t)
#    out1_list[i] =  out1
#    out2_list[i] =  out2
    
#plt.figure(figsize=(12,4))
#plt.plot(t_vec,out2_list)
#plt.plot(t_vec,out1_list)

# %%
fig = plt.figure(figsize=(10,10))
# QPE 
ax = fig.add_subplot(321)
t_vec = np.arange(0,10,1/144)
out1_list = np.zeros(t_vec.shape)
out2_list = np.zeros(t_vec.shape)

for i,t in enumerate(t_vec):
    out1,out2 = QPE_fun(t)
    out1_list[i] =  out1
    out2_list[i] =  out2
ax.plot(t_vec,out2_list)
ax.plot(t_vec,out1_list)
ax.set_xlabel("Time,days")
ax.set_ylabel("QPE, m3/d")

# TKN
ax = fig.add_subplot(323)
t_vec = np.arange(0,10,1/144)
out1_list = np.zeros(t_vec.shape)
out2_list = np.zeros(t_vec.shape)

for i,t in enumerate(t_vec):
    out1,out2 = TKN_fun(t)
    out1_list[i] =  out1
    out2_list[i] =  out2
ax.plot(t_vec,out2_list)
ax.plot(t_vec,out1_list)
ax.set_xlabel("Time,days")
ax.set_ylabel("TKN, mg-N/L")

# SO1
ax = fig.add_subplot(322)
t_vec = np.arange(0,10,1/144)
out1_list = np.zeros(t_vec.shape)
out2_list = np.zeros(t_vec.shape)

for i,t in enumerate(t_vec):
    out1,out2 = SO1_fun(t)
    out1_list[i] =  out1
    out2_list[i] =  out2
ax.plot(t_vec,out2_list)
ax.plot(t_vec,out1_list)
ax.set_xlabel("Time,days")
ax.set_ylabel("SO1, mg/L")

# SO2
ax = fig.add_subplot(324)
t_vec = np.arange(0,10,1/144)
out1_list = np.zeros(t_vec.shape)
out2_list = np.zeros(t_vec.shape)

for i,t in enumerate(t_vec):
    out1,out2 = SO2_fun(t)
    out1_list[i] =  out1
    out2_list[i] =  out2
ax.plot(t_vec,out2_list)
ax.plot(t_vec,out1_list)
ax.set_xlabel("Time,days")
ax.set_ylabel("SO2, mg/L")

# SO3
ax = fig.add_subplot(326)
t_vec = np.arange(0,10,1/144)
out1_list = np.zeros(t_vec.shape)
out2_list = np.zeros(t_vec.shape)

for i,t in enumerate(t_vec):
    out1,out2 = SO3_fun(t)
    out1_list[i] =  out1
    out2_list[i] =  out2
ax.plot(t_vec,out2_list)
ax.plot(t_vec,out1_list)
ax.set_xlabel("Time,days")
ax.set_ylabel("SO3, mg/L")
# Out:
# Text(0, 0.5, 'SO3, mg/L')
# 530021 Set: Sumo__DataComm to 3600000
# 530021 Set: Sumo__PlantName to C:\Users\28417\AppData\Local\Dynamita\Sumo20\.tmp\1zmcvkck.uxg\sumoproject.xml
# 530049 Core loop started.
# 530011 Reset
# 530036 Script file C:/Users/28417/Desktop/MIMO_control_design_for_MLE/script_Initialize.scs loaded.
# 530007 Path set to: "C:/Users/28417/Desktop/MIMO_control_design_for_MLE".
# 530020 Set mode: dynamic
# 530021 Set: Sumo__Plant__param__Sumo1__KNHx_NITO_AS to 0.5
# 530021 Set: Sumo__Plant__CSTR2__param__Sumo1__KNHx_NITO_AS to 0.5
# 530021 Set: Sumo__Plant__CSTR3__param__Sumo1__KNHx_NITO_AS to 0.5
# 530021 Set: Sumo__Plant__CSTR4__param__Sumo1__KNHx_NITO_AS to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__Sideflowdivider1__param__Qpumped_target to 600
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__CSTR1__param__L_Vtrain to 2000
# 530021 Set: Sumo__Plant__CSTR1__param__SO2 to 0
# 530021 Set: Sumo__Plant__CSTR2__param__L_Vtrain to 2000
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR2__param__SNHx_0 to 5.4
# 530021 Set: Sumo__Plant__CSTR2__param__Sumo1__KO2_NITO_AS to 0.6
# 530021 Set: Sumo__Plant__CSTR3__param__L_Vtrain to 2000
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SNHx_0 to 2.4
# 530021 Set: Sumo__Plant__CSTR3__param__Sumo1__KO2_NITO_AS to 0.4
# 530021 Set: Sumo__Plant__CSTR4__param__L_Vtrain to 2000
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SNHx_0 to 0.4
# 530021 Set: Sumo__Plant__CSTR4__param__Sumo1__KO2_NITO_AS to 0.2

# %% [markdown]
# # Step 4: Define SUMO-python communication
#
# I'd like SUMO to sample signals every 1 minute and the observer updates every 10 minutes

# %%
# Simulation time setting for SUMO 
stop_days = 10
sumo.set_stopTime(stop_days*dur.day)

# Set commnunication frequency between SUMO and python 
comm_freq = 1 # in minutes
sumo.data_communicate_interval = comm_freq*dur.min # every minute

obser_freq = 10 # in minutes

# %%
def datacomm_callback(sumo):
    global true_pd
    global noise_pd
    global ekf
    # For every miniutes,update the input of the flow 
    # Input QPE
    QPE, QPE_n = QPE_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__Influent1__param__Q ' + str(QPE) + ';'
    sumo.send_command(command)
    
    # Input QRAS
    QRAS, QRAS_n = QRAS_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__Clarifier1__param__Qsludge_target ' + str(QRAS) + ';'
    sumo.send_command(command)
    
    # Input QMLE
    QMLE, QMLE_n = QMLE_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target ' + str(QMLE) + ';'
    sumo.send_command(command)
    
    # Input TKN
    TKN, TKN_n = TKN_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__Influent1__param__TKN ' + str(TKN) + ';'
    sumo.send_command(command)
    
    # Input SO1
    SO1, SO1_n = SO1_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__CSTR2__param__SO2 ' + str(SO1) + ';'
    sumo.send_command(command)
    
    # Input SO2
    SO2, SO2_n = SO2_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__CSTR3__param__SO2 ' + str(SO2) + ';'
    sumo.send_command(command)
    
    # Input SO3
    SO3, SO3_n = SO3_fun(sumo.time_ms()/dur.day)
    command = 'set Sumo__Plant__CSTR4__param__SO2 ' + str(SO3) + ';'
    sumo.send_command(command)
   
    # Extract effluent ammonia information
    SNH1 = sumo.SV(b'Sumo__Plant__CSTR2__SNHx')
    SNH1_n = SNH1 + SNH1*0.1*np.random.randn(1).astype(float)[0]
    
    SNH2 = sumo.SV(b'Sumo__Plant__CSTR3__SNHx')
    SNH2_n = SNH2 + 0.3*np.random.randn(1).astype(float)[0]
    
    SNH3 = sumo.SV(b'Sumo__Plant__CSTR4__SNHx')
    SNH3_n = SNH3 + 0.1*np.random.randn(1).astype(float)[0]
       
    # Store all data in the the dataframe 
    t= np.array([sumo.time_ms()/dur.day])
    
    u = np.array([QPE,QRAS,QMLE,TKN,SO1,SO2,SO3])
    u_n = np.array([QPE_n,QRAS_n,QMLE_n,TKN_n,SO1_n,SO2_n,SO3_n])
    
    x = np.array([SNH1,SNH2,SNH3])
    x_n= np.array([SNH1_n,SNH2_n,SNH3_n])
    
    true_pd.loc[len(true_pd)] = np.concatenate((t,u,x),axis = 0)
    noise_pd.loc[len(noise_pd)] = np.concatenate((t,u_n,x_n),axis = 0)
    
    ekf.predict(u_n)
    
    z = np.array([x_n[2]])
    ekf.ekf_update(z)
    EKF_estiamte.loc[len(EKF_estiamte)] = np.concatenate((t,ekf.x.reshape(-1)),axis = 0)
    if sumo.time_ms()%dur.day==0:
        print(sumo.time_days(), "days\t")
    return 0

# Register the datacomm_callback
sumo.add_datacomm_callback(datacomm_callback)
# Out:
# 530021 Set: Sumo__StopTime to 864000000

# %%
global true_pd
global noise_pd
global EKF_estiamte
true_pd = pd.DataFrame(columns=['Time','QPE','QRAS','QMLE','TKN','SO1','SO2','SO3','SNH1','SNH2','SNH3'])
noise_pd = true_pd.copy()
EKF_estiamte =pd.DataFrame(columns=['Time','SNH1','SNH2','SNH3','r'])
global ekf
in_cov = np.diag([500,500,500,3,0.1,0.1,0.1])
ekf = MLEEKF(in_cov)
ekf.x = np.array([5,1.5,0.4,-325])
ekf.P = np.diag([1, 0.1, 0.1, 10])
ekf.Q = np.diag([1, 1, 1, 10])
ekf.R = 1

track = []

# %%
sumo.run_model()
while not sumo.simulation_finished:
    time.sleep(0.01)
# Out:
# 530002 Simulation started.
# 0.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 1.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 2.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 3.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5187
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.01309
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.507478
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.53739
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.02617
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.514946
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.55607
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.03925
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.522393
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.57473
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.05231
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.529808
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.59336
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.06535
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.537182
# 530021 Set: Sumo__Plant__Influent1__param__Q to 29000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.61196
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.07838
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.544504
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.63053
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.09137
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.551764
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.64904
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.10433
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.558951
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.66751
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.11725
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.566056
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.68591
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.13014
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.573068
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.70425
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.14298
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.579978
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.72252
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.15576
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.586777
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.74071
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.1685
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.593454
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.75882
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.18117
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.6
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.77684
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.19378
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.606406
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.79476
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.20633
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.612664
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.81257
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.2188
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.618764
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.83028
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.2312
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.624698
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.84787
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.24351
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.630457
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.86534
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.25574
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.636035
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.88268
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.26788
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.641421
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.89989
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.27992
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.64661
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.91696
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.29187
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.651594
# 4.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.93388
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.30372
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.656366
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.95065
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.31546
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.66092
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.96727
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.32709
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.665248
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.98372
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.3386
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.669345
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.35
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.673205
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.01611
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.36127
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.676823
# 530021 Set: Sumo__Plant__Influent1__param__Q to 29000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.03203
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.37242
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.680194
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.04777
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.38344
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.683312
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.06332
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.39432
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.686175
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.07867
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.40507
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.688777
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.09382
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.41567
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.691115
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.10876
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.42613
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.693185
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.12349
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.43644
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.694986
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.138
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.4466
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.696513
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.15229
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.4566
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.697766
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.16635
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.46644
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.698742
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.18017
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.47612
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.699441
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.19376
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.48563
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.69986
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.20711
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.49497
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.7
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.22021
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.50414
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.69986
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.23305
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.51314
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.699441
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# ...
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.302234
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.138
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.4466
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.303487
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.12349
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.43644
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.305014
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.10876
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.42613
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.306815
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.09382
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.41567
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.308885
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.07867
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.40507
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.311223
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.06332
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.39432
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.313825
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.04777
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.38344
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.316688
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.03203
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.37242
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.319806
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2.01611
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.36127
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.323177
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 2
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.35
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.326795
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.98372
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.3386
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.330655
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.96727
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.32709
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.334752
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.95065
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.31546
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.33908
# 9.0 days
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.93388
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.30372
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.343634
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.91696
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.29187
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.348406
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.89989
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.27992
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.35339
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.88268
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.26788
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.358579
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.86534
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.25574
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.363965
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.84787
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.24351
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.369543
# 530021 Set: Sumo__Plant__Influent1__param__Q to 29000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.83028
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.2312
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.375302
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28829.6
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 66.2593
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.81257
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.2188
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.381236
# 530021 Set: Sumo__Plant__Influent1__param__Q to 28330.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 65.2603
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.79476
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.20633
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.387336
# 530021 Set: Sumo__Plant__Influent1__param__Q to 27535.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 63.6711
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.77684
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.19378
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.393594
# 530021 Set: Sumo__Plant__Influent1__param__Q to 26500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 61.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.75882
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.18117
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.4
# 530021 Set: Sumo__Plant__Influent1__param__Q to 25294.1
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 59.1882
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.74071
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.1685
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.406546
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.72252
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.15576
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.413223
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.70425
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.14298
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.420022
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.68591
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.13014
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.426932
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.66751
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.11725
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.433944
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.64904
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.10433
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.441049
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.63053
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.09137
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.448236
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.61196
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.07838
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.455496
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19170.4
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 46.9407
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.59336
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.06535
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.462818
# 530021 Set: Sumo__Plant__Influent1__param__Q to 19669.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 47.9397
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.57473
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.05231
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.470192
# 530021 Set: Sumo__Plant__Influent1__param__Q to 20464.5
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 49.5289
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.55607
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.03925
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.477607
# 530021 Set: Sumo__Plant__Influent1__param__Q to 21500
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 51.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.53739
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.02617
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.485054
# 530021 Set: Sumo__Plant__Influent1__param__Q to 22705.9
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 54.0118
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5187
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1.01309
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.492522
# 10.0 days
# 530004 Simulation ended.
# 530021 Set: Sumo__Plant__Influent1__param__Q to 24000
# 530021 Set: Sumo__Plant__Clarifier1__param__Qsludge_target to 24000
# 530021 Set: Sumo__Plant__Sideflowdivider1_1__param__Qpumped_target to 36000
# 530021 Set: Sumo__Plant__Influent1__param__TKN to 56.6
# 530021 Set: Sumo__Plant__CSTR2__param__SO2 to 1.5
# 530021 Set: Sumo__Plant__CSTR3__param__SO2 to 1
# 530021 Set: Sumo__Plant__CSTR4__param__SO2 to 0.5

# %%
plt.figure(figsize=(12,4))
plt.plot(true_pd.Time,true_pd.SNH1)
plt.plot(noise_pd.Time,noise_pd.SNH1)
plt.plot(EKF_estiamte.Time,EKF_estiamte.SNH1)
plt.legend(['True','Measurement','Estimation'])

# %%
plt.figure(figsize=(12,4))
plt.plot(true_pd.Time,true_pd.SNH2)
plt.plot(noise_pd.Time,noise_pd.SNH2)
plt.plot(EKF_estiamte.Time,EKF_estiamte.SNH2)
plt.legend(['True','Measurement','Estimation'])

# %%
plt.figure(figsize=(12,4))
plt.plot(true_pd.Time,true_pd.SNH3)
plt.plot(noise_pd.Time,noise_pd.SNH3)
plt.plot(EKF_estiamte.Time,EKF_estiamte.SNH3)
plt.legend(['True','Measurement','Estimation'])

# %%
plt.figure(figsize=(12,4))
plt.plot(EKF_estiamte.Time,-EKF_estiamte.r)

# %%
with pd.ExcelWriter('C:/Users/28417/Desktop/Greybox Wrapup/Tables.xlsx',
                    mode='a') as writer:  
    EKF_estiamte.to_excel(writer, sheet_name='EKF_estimate')
    true_pd.to_excel(writer, sheet_name='true_pd')
    noise_pd.to_excel(writer, sheet_name='noise_pd')
